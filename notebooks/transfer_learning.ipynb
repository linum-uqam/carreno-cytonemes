# %% [markdown]
# # Transfer learning
# Transfer learning is a vital part for saving time during model training

# %%
import tifffile as tif
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras
import pandas as pd
import carreno.nn.unet as unet
import carreno.nn.layers as ly

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 2D weights to 3D
# We would like to transfer the weights from a 2D UNet to a 3D UNet

# %%
# create 2D UNet
unet2D = unet.UNet([64,64,1], n_class=3, depth=3, top_activation="relu")
model = unet2D
model.summary()
# Out:
# create norm relu
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 64)   640         ['input_2[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 64)  256         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_14[0][0]']
#
#  dropout_14 (Dropout)           (None, 64, 64, 64)   0           ['activation_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 64)  256         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_15[0][0]']
#
#  dropout_15 (Dropout)           (None, 64, 64, 64)   0           ['activation_16[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 64)  0           ['dropout_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 128)  73856       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 128)  512        ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_16[0][0]']
#
#  dropout_16 (Dropout)           (None, 32, 32, 128)  0           ['activation_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 128)  147584      ['dropout_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_17[0][0]']
#
#  dropout_17 (Dropout)           (None, 32, 32, 128)  0           ['activation_18[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 128)  0          ['dropout_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 256)  295168      ['max_pooling2d_4[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_18[0][0]']
#
#  dropout_18 (Dropout)           (None, 16, 16, 256)  0           ['activation_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 256)  590080      ['dropout_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_19[0][0]']
#
#  dropout_19 (Dropout)           (None, 16, 16, 256)  0           ['activation_20[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 8, 8, 256)   0           ['dropout_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 8, 8, 256)    590080      ['max_pooling2d_5[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_20[0][0]']
#
#  dropout_20 (Dropout)           (None, 8, 8, 256)    0           ['activation_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 8, 8, 256)    590080      ['dropout_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_21[0][0]']
#
#  dropout_21 (Dropout)           (None, 8, 8, 256)    0           ['activation_22[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 16, 16, 256)  262400     ['dropout_21[0][0]']
#  spose)
#
#  concatenate_3 (Concatenate)    (None, 16, 16, 512)  0           ['dropout_19[0][0]',
#                                                                   'conv2d_transpose_3[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 16, 16, 256)  1179904     ['concatenate_3[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_22[0][0]']
#
#  dropout_22 (Dropout)           (None, 16, 16, 256)  0           ['activation_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 16, 16, 256)  590080      ['dropout_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_23[0][0]']
#
#  dropout_23 (Dropout)           (None, 16, 16, 256)  0           ['activation_24[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 32, 32, 128)  131200     ['dropout_23[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 256)  0           ['dropout_17[0][0]',
#                                                                   'conv2d_transpose_4[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate_4[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 128)  512        ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_24[0][0]']
#
#  dropout_24 (Dropout)           (None, 32, 32, 128)  0           ['activation_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 128)  147584      ['dropout_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 128)  512        ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_25[0][0]']
#
#  dropout_25 (Dropout)           (None, 32, 32, 128)  0           ['activation_26[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 64, 64, 64)  32832       ['dropout_25[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 128)  0           ['dropout_15[0][0]',
#                                                                   'conv2d_transpose_5[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_5[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 64, 64, 64)  256         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_26[0][0]']
#
#  dropout_26 (Dropout)           (None, 64, 64, 64)   0           ['activation_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 64, 64, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_27[0][0]']
#
#  dropout_27 (Dropout)           (None, 64, 64, 64)   0           ['activation_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 64, 64, 3)    195         ['dropout_27[0][0]']
#
#  activation_29 (Activation)     (None, 64, 64, 3)    0           ['conv2d_29[0][0]']
#
#  relu_normalization_1 (ReluNorm  (None, 64, 64, 3)   0           ['activation_29[0][0]']
#  alization)
#
# ==================================================================================================
# Total params: 5,083,587
# Trainable params: 5,078,979
# Non-trainable params: 4,608
# __________________________________________________________________________________________________

# %%
# set fake weights
layer = model.layers[1].get_weights()[0]
layer[:] = 1  # all weights will be 1
model.layers[1].set_weights([layer, model.layers[1].get_weights()[1]])

# %%
# create 3D UNet from 2D UNet
unet3D = ly.model2D_to_3D(model, 16)

# %%
# if everything went well, our fake weights should be averaged in this layer
layer3D = unet3D.layers[1].get_weights()[0]
print("Old shape :", layer.shape)
print("New shape :", layer3D.shape)
print('---')
print("Old weights :", np.unique(layer))
print("New weights :", np.unique(layer3D))
# Out:
# Old shape : (3, 3, 1, 64)
# New shape : (3, 3, 3, 1, 64)
# ---
# Old weights : [1.]
# New weights : [0.33333334]

# %%
unet3D.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 16, 64, 64,  0           []
#                                  1)]
#
#  conv3d (Conv3D)                (None, 16, 64, 64,   1792        ['input_3[0][0]']
#                                 64)
#
#  batch_normalization_28 (BatchN  (None, 16, 64, 64,   256        ['conv3d[0][0]']
#  ormalization)                  64)
#
#  activation_15 (Activation)     multiple             0           ['batch_normalization_28[0][0]']
#
#  dropout_14 (Dropout)           multiple             0           ['activation_15[1][0]']
#
#  conv3d_1 (Conv3D)              (None, 16, 64, 64,   110656      ['dropout_14[1][0]']
#                                 64)
#
#  batch_normalization_29 (BatchN  (None, 16, 64, 64,   256        ['conv3d_1[0][0]']
#  ormalization)                  64)
#
#  activation_16 (Activation)     multiple             0           ['batch_normalization_29[0][0]']
#
#  dropout_15 (Dropout)           multiple             0           ['activation_16[1][0]']
#
#  max_pooling3d (MaxPooling3D)   (None, 8, 32, 32, 6  0           ['dropout_15[1][0]']
#                                 4)
#
#  conv3d_2 (Conv3D)              (None, 8, 32, 32, 1  221312      ['max_pooling3d[0][0]']
#                                 28)
#
#  batch_normalization_30 (BatchN  (None, 8, 32, 32, 1  512        ['conv3d_2[0][0]']
#  ormalization)                  28)
#
#  activation_17 (Activation)     multiple             0           ['batch_normalization_30[0][0]']
#
#  dropout_16 (Dropout)           multiple             0           ['activation_17[1][0]']
#
#  conv3d_3 (Conv3D)              (None, 8, 32, 32, 1  442496      ['dropout_16[1][0]']
#                                 28)
#
#  batch_normalization_31 (BatchN  (None, 8, 32, 32, 1  512        ['conv3d_3[0][0]']
#  ormalization)                  28)
#
#  activation_18 (Activation)     multiple             0           ['batch_normalization_31[0][0]']
#
#  dropout_17 (Dropout)           multiple             0           ['activation_18[1][0]']
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 4, 16, 16, 1  0          ['dropout_17[1][0]']
#                                 28)
#
#  conv3d_4 (Conv3D)              (None, 4, 16, 16, 2  884992      ['max_pooling3d_1[0][0]']
#                                 56)
#
#  batch_normalization_32 (BatchN  (None, 4, 16, 16, 2  1024       ['conv3d_4[0][0]']
#  ormalization)                  56)
#
#  activation_19 (Activation)     multiple             0           ['batch_normalization_32[0][0]']
#
#  dropout_18 (Dropout)           multiple             0           ['activation_19[1][0]']
#
#  conv3d_5 (Conv3D)              (None, 4, 16, 16, 2  1769728     ['dropout_18[1][0]']
#                                 56)
#
#  batch_normalization_33 (BatchN  (None, 4, 16, 16, 2  1024       ['conv3d_5[0][0]']
#  ormalization)                  56)
#
#  activation_20 (Activation)     multiple             0           ['batch_normalization_33[0][0]']
#
#  dropout_19 (Dropout)           multiple             0           ['activation_20[1][0]']
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 2, 8, 8, 256  0          ['dropout_19[1][0]']
#                                 )
#
#  conv3d_6 (Conv3D)              (None, 2, 8, 8, 256  1769728     ['max_pooling3d_2[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 2, 8, 8, 256  1024       ['conv3d_6[0][0]']
#  ormalization)                  )
#
#  activation_21 (Activation)     multiple             0           ['batch_normalization_34[0][0]']
#
#  dropout_20 (Dropout)           multiple             0           ['activation_21[1][0]']
#
#  conv3d_7 (Conv3D)              (None, 2, 8, 8, 256  1769728     ['dropout_20[1][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 2, 8, 8, 256  1024       ['conv3d_7[0][0]']
#  ormalization)                  )
#
#  activation_22 (Activation)     multiple             0           ['batch_normalization_35[0][0]']
#
#  dropout_21 (Dropout)           multiple             0           ['activation_22[1][0]']
#
#  conv3d_transpose (Conv3DTransp  (None, 4, 16, 16, 2  524544     ['dropout_21[1][0]']
#  ose)                           56)
#
#  concatenate_6 (Concatenate)    (None, 4, 16, 16, 5  0           ['dropout_19[1][0]',
#                                 12)                               'conv3d_transpose[0][0]']
#
#  conv3d_8 (Conv3D)              (None, 4, 16, 16, 2  3539200     ['concatenate_6[0][0]']
#                                 56)
#
#  batch_normalization_36 (BatchN  (None, 4, 16, 16, 2  1024       ['conv3d_8[0][0]']
#  ormalization)                  56)
#
#  activation_23 (Activation)     multiple             0           ['batch_normalization_36[0][0]']
#
#  dropout_22 (Dropout)           multiple             0           ['activation_23[1][0]']
#
#  conv3d_9 (Conv3D)              (None, 4, 16, 16, 2  1769728     ['dropout_22[1][0]']
#                                 56)
#
#  batch_normalization_37 (BatchN  (None, 4, 16, 16, 2  1024       ['conv3d_9[0][0]']
#  ormalization)                  56)
#
#  activation_24 (Activation)     multiple             0           ['batch_normalization_37[0][0]']
#
#  dropout_23 (Dropout)           multiple             0           ['activation_24[1][0]']
#
#  conv3d_transpose_1 (Conv3DTran  (None, 8, 32, 32, 1  262272     ['dropout_23[1][0]']
#  spose)                         28)
#
#  concatenate_7 (Concatenate)    (None, 8, 32, 32, 2  0           ['dropout_17[1][0]',
#                                 56)                               'conv3d_transpose_1[0][0]']
#
#  conv3d_10 (Conv3D)             (None, 8, 32, 32, 1  884864      ['concatenate_7[0][0]']
#                                 28)
#
#  batch_normalization_38 (BatchN  (None, 8, 32, 32, 1  512        ['conv3d_10[0][0]']
#  ormalization)                  28)
#
#  activation_25 (Activation)     multiple             0           ['batch_normalization_38[0][0]']
#
#  dropout_24 (Dropout)           multiple             0           ['activation_25[1][0]']
#
#  conv3d_11 (Conv3D)             (None, 8, 32, 32, 1  442496      ['dropout_24[1][0]']
#                                 28)
#
#  batch_normalization_39 (BatchN  (None, 8, 32, 32, 1  512        ['conv3d_11[0][0]']
#  ormalization)                  28)
#
#  activation_26 (Activation)     multiple             0           ['batch_normalization_39[0][0]']
#
#  dropout_25 (Dropout)           multiple             0           ['activation_26[1][0]']
#
#  conv3d_transpose_2 (Conv3DTran  (None, 16, 64, 64,   65600      ['dropout_25[1][0]']
#  spose)                         64)
#
#  concatenate_8 (Concatenate)    (None, 16, 64, 64,   0           ['dropout_15[1][0]',
#                                 128)                              'conv3d_transpose_2[0][0]']
#
#  conv3d_12 (Conv3D)             (None, 16, 64, 64,   221248      ['concatenate_8[0][0]']
#                                 64)
#
#  batch_normalization_40 (BatchN  (None, 16, 64, 64,   256        ['conv3d_12[0][0]']
#  ormalization)                  64)
#
#  activation_27 (Activation)     multiple             0           ['batch_normalization_40[0][0]']
#
#  dropout_26 (Dropout)           multiple             0           ['activation_27[1][0]']
#
#  conv3d_13 (Conv3D)             (None, 16, 64, 64,   110656      ['dropout_26[1][0]']
#                                 64)
#
#  batch_normalization_41 (BatchN  (None, 16, 64, 64,   256        ['conv3d_13[0][0]']
#  ormalization)                  64)
#
#  activation_28 (Activation)     multiple             0           ['batch_normalization_41[0][0]']
#
#  dropout_27 (Dropout)           multiple             0           ['activation_28[1][0]']
#
#  conv3d_14 (Conv3D)             (None, 16, 64, 64,   195         ['dropout_27[1][0]']
#                                 3)
#
#  activation_29 (Activation)     multiple             0           ['conv3d_14[0][0]']
#
#  relu_normalization_1 (ReluNorm  multiple            0           ['activation_29[1][0]']
#  alization)
#
# ==================================================================================================
# Total params: 14,800,451
# Trainable params: 14,795,843
# Non-trainable params: 4,608
# __________________________________________________________________________________________________

# %%
# we could use an approach which map every layer name with a 2D and 3D fonction for a very general conversion
inp = tf.keras.layers.Input([16, 64, 64, 1])
print("nb layers", len(model.layers))
for i, layer in enumerate(model.layers):
    name = layer.name.rsplit('_', 1)[0]
    print('-layer{:<2} {:<20}'.format(i, name), end="")
    
    t = "?"
    input_name = 'input'
    conv2d_name = 'conv2d'
    conv2d_transpose_name = 'conv2d_transpose'
    batch_norm_name = 'batch_normalization'
    leaky_relu_name = 'leaky_re_lu'
    max_pooling2d_name = 'max_pooling2d'
    concatenate_name = 'concatenate'
    
    if input_name == name:
        t = input_name
    elif conv2d_name == name:
        t = conv2d_name
    elif conv2d_transpose_name == name:
        t = conv2d_transpose_name
    elif batch_norm_name == name:
        t = batch_norm_name
    elif leaky_relu_name == name:
        t = leaky_relu_name
    elif max_pooling2d_name == name:
        t = max_pooling2d_name
    elif concatenate_name == name:
        t = concatenate_name
    
    print(' type {:<20}'.format(t), 'do something?', '2d' in name or name == concatenate_name)
# Out:
# nb layers 69
# -layer0  input                type input                do something? False
# -layer1  conv2d               type conv2d               do something? True
# -layer2  batch_normalization  type batch_normalization  do something? False
# -layer3  activation           type ?                    do something? False
# -layer4  dropout              type ?                    do something? False
# -layer5  conv2d               type conv2d               do something? True
# -layer6  batch_normalization  type batch_normalization  do something? False
# -layer7  activation           type ?                    do something? False
# -layer8  dropout              type ?                    do something? False
# -layer9  max_pooling2d        type max_pooling2d        do something? True
# -layer10 conv2d               type conv2d               do something? True
# -layer11 batch_normalization  type batch_normalization  do something? False
# -layer12 activation           type ?                    do something? False
# -layer13 dropout              type ?                    do something? False
# -layer14 conv2d               type conv2d               do something? True
# -layer15 batch_normalization  type batch_normalization  do something? False
# -layer16 activation           type ?                    do something? False
# -layer17 dropout              type ?                    do something? False
# -layer18 max_pooling2d        type max_pooling2d        do something? True
# -layer19 conv2d               type conv2d               do something? True
# -layer20 batch_normalization  type batch_normalization  do something? False
# -layer21 activation           type ?                    do something? False
# -layer22 dropout              type ?                    do something? False
# -layer23 conv2d               type conv2d               do something? True
# -layer24 batch_normalization  type batch_normalization  do something? False
# -layer25 activation           type ?                    do something? False
# -layer26 dropout              type ?                    do something? False
# -layer27 max_pooling2d        type max_pooling2d        do something? True
# -layer28 conv2d               type conv2d               do something? True
# -layer29 batch_normalization  type batch_normalization  do something? False
# -layer30 activation           type ?                    do something? False
# -layer31 dropout              type ?                    do something? False
# -layer32 conv2d               type conv2d               do something? True
# -layer33 batch_normalization  type batch_normalization  do something? False
# -layer34 activation           type ?                    do something? False
# -layer35 dropout              type ?                    do something? False
# -layer36 conv2d_transpose     type conv2d_transpose     do something? True
# -layer37 concatenate          type concatenate          do something? True
# -layer38 conv2d               type conv2d               do something? True
# -layer39 batch_normalization  type batch_normalization  do something? False
# -layer40 activation           type ?                    do something? False
# -layer41 dropout              type ?                    do something? False
# -layer42 conv2d               type conv2d               do something? True
# -layer43 batch_normalization  type batch_normalization  do something? False
# -layer44 activation           type ?                    do something? False
# -layer45 dropout              type ?                    do something? False
# -layer46 conv2d_transpose     type conv2d_transpose     do something? True
# -layer47 concatenate          type concatenate          do something? True
# -layer48 conv2d               type conv2d               do something? True
# -layer49 batch_normalization  type batch_normalization  do something? False
# -layer50 activation           type ?                    do something? False
# -layer51 dropout              type ?                    do something? False
# -layer52 conv2d               type conv2d               do something? True
# -layer53 batch_normalization  type batch_normalization  do something? False
# -layer54 activation           type ?                    do something? False
# -layer55 dropout              type ?                    do something? False
# -layer56 conv2d_transpose     type conv2d_transpose     do something? True
# -layer57 concatenate          type concatenate          do something? True
# -layer58 conv2d               type conv2d               do something? True
# -layer59 batch_normalization  type batch_normalization  do something? False
# -layer60 activation           type ?                    do something? False
# -layer61 dropout              type ?                    do something? False
# -layer62 conv2d               type conv2d               do something? True
# -layer63 batch_normalization  type batch_normalization  do something? False
# -layer64 activation           type ?                    do something? False
# -layer65 dropout              type ?                    do something? False
# -layer66 conv2d               type conv2d               do something? True
# -layer67 activation           type ?                    do something? False
# -layer68 relu_normalization   type ?                    do something? False

# %%
# test save and load
unet3D.save_weights("test.h5")
newUnet3D = unet.UNet([16, 64,64,1], n_class=3, depth=3, top_activation="relu")
newUnet3D.load_weights("test.h5")
newUnet3D.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 16, 64, 64,  0           []
#                                  1)]
#
#  conv3d_60 (Conv3D)             (None, 16, 64, 64,   1792        ['input_10[0][0]']
#                                 64)
#
#  batch_normalization_98 (BatchN  (None, 16, 64, 64,   256        ['conv3d_60[0][0]']
#  ormalization)                  64)
#
#  activation_90 (Activation)     (None, 16, 64, 64,   0           ['batch_normalization_98[0][0]']
#                                 64)
#
#  dropout_84 (Dropout)           (None, 16, 64, 64,   0           ['activation_90[0][0]']
#                                 64)
#
#  conv3d_61 (Conv3D)             (None, 16, 64, 64,   110656      ['dropout_84[0][0]']
#                                 64)
#
#  batch_normalization_99 (BatchN  (None, 16, 64, 64,   256        ['conv3d_61[0][0]']
#  ormalization)                  64)
#
#  activation_91 (Activation)     (None, 16, 64, 64,   0           ['batch_normalization_99[0][0]']
#                                 64)
#
#  dropout_85 (Dropout)           (None, 16, 64, 64,   0           ['activation_91[0][0]']
#                                 64)
#
#  max_pooling3d_12 (MaxPooling3D  (None, 8, 32, 32, 6  0          ['dropout_85[0][0]']
#  )                              4)
#
#  conv3d_62 (Conv3D)             (None, 8, 32, 32, 1  221312      ['max_pooling3d_12[0][0]']
#                                 28)
#
#  batch_normalization_100 (Batch  (None, 8, 32, 32, 1  512        ['conv3d_62[0][0]']
#  Normalization)                 28)
#
#  activation_92 (Activation)     (None, 8, 32, 32, 1  0           ['batch_normalization_100[0][0]']
#                                 28)
#
#  dropout_86 (Dropout)           (None, 8, 32, 32, 1  0           ['activation_92[0][0]']
#                                 28)
#
#  conv3d_63 (Conv3D)             (None, 8, 32, 32, 1  442496      ['dropout_86[0][0]']
#                                 28)
#
#  batch_normalization_101 (Batch  (None, 8, 32, 32, 1  512        ['conv3d_63[0][0]']
#  Normalization)                 28)
#
#  activation_93 (Activation)     (None, 8, 32, 32, 1  0           ['batch_normalization_101[0][0]']
#                                 28)
#
#  dropout_87 (Dropout)           (None, 8, 32, 32, 1  0           ['activation_93[0][0]']
#                                 28)
#
#  max_pooling3d_13 (MaxPooling3D  (None, 4, 16, 16, 1  0          ['dropout_87[0][0]']
#  )                              28)
#
#  conv3d_64 (Conv3D)             (None, 4, 16, 16, 2  884992      ['max_pooling3d_13[0][0]']
#                                 56)
#
#  batch_normalization_102 (Batch  (None, 4, 16, 16, 2  1024       ['conv3d_64[0][0]']
#  Normalization)                 56)
#
#  activation_94 (Activation)     (None, 4, 16, 16, 2  0           ['batch_normalization_102[0][0]']
#                                 56)
#
#  dropout_88 (Dropout)           (None, 4, 16, 16, 2  0           ['activation_94[0][0]']
#                                 56)
#
#  conv3d_65 (Conv3D)             (None, 4, 16, 16, 2  1769728     ['dropout_88[0][0]']
#                                 56)
#
#  batch_normalization_103 (Batch  (None, 4, 16, 16, 2  1024       ['conv3d_65[0][0]']
#  Normalization)                 56)
#
#  activation_95 (Activation)     (None, 4, 16, 16, 2  0           ['batch_normalization_103[0][0]']
#                                 56)
#
#  dropout_89 (Dropout)           (None, 4, 16, 16, 2  0           ['activation_95[0][0]']
#                                 56)
#
#  max_pooling3d_14 (MaxPooling3D  (None, 2, 8, 8, 256  0          ['dropout_89[0][0]']
#  )                              )
#
#  conv3d_66 (Conv3D)             (None, 2, 8, 8, 256  1769728     ['max_pooling3d_14[0][0]']
#                                 )
#
#  batch_normalization_104 (Batch  (None, 2, 8, 8, 256  1024       ['conv3d_66[0][0]']
#  Normalization)                 )
#
#  activation_96 (Activation)     (None, 2, 8, 8, 256  0           ['batch_normalization_104[0][0]']
#                                 )
#
#  dropout_90 (Dropout)           (None, 2, 8, 8, 256  0           ['activation_96[0][0]']
#                                 )
#
#  conv3d_67 (Conv3D)             (None, 2, 8, 8, 256  1769728     ['dropout_90[0][0]']
#                                 )
#
#  batch_normalization_105 (Batch  (None, 2, 8, 8, 256  1024       ['conv3d_67[0][0]']
#  Normalization)                 )
#
#  activation_97 (Activation)     (None, 2, 8, 8, 256  0           ['batch_normalization_105[0][0]']
#                                 )
#
#  dropout_91 (Dropout)           (None, 2, 8, 8, 256  0           ['activation_97[0][0]']
#                                 )
#
#  conv3d_transpose_12 (Conv3DTra  (None, 4, 16, 16, 2  524544     ['dropout_91[0][0]']
#  nspose)                        56)
#
#  concatenate_21 (Concatenate)   (None, 4, 16, 16, 5  0           ['dropout_89[0][0]',
#                                 12)                               'conv3d_transpose_12[0][0]']
#
#  conv3d_68 (Conv3D)             (None, 4, 16, 16, 2  3539200     ['concatenate_21[0][0]']
#                                 56)
#
#  batch_normalization_106 (Batch  (None, 4, 16, 16, 2  1024       ['conv3d_68[0][0]']
#  Normalization)                 56)
#
#  activation_98 (Activation)     (None, 4, 16, 16, 2  0           ['batch_normalization_106[0][0]']
#                                 56)
#
#  dropout_92 (Dropout)           (None, 4, 16, 16, 2  0           ['activation_98[0][0]']
#                                 56)
#
#  conv3d_69 (Conv3D)             (None, 4, 16, 16, 2  1769728     ['dropout_92[0][0]']
#                                 56)
#
#  batch_normalization_107 (Batch  (None, 4, 16, 16, 2  1024       ['conv3d_69[0][0]']
#  Normalization)                 56)
#
#  activation_99 (Activation)     (None, 4, 16, 16, 2  0           ['batch_normalization_107[0][0]']
#                                 56)
#
#  dropout_93 (Dropout)           (None, 4, 16, 16, 2  0           ['activation_99[0][0]']
#                                 56)
#
#  conv3d_transpose_13 (Conv3DTra  (None, 8, 32, 32, 1  262272     ['dropout_93[0][0]']
#  nspose)                        28)
#
#  concatenate_22 (Concatenate)   (None, 8, 32, 32, 2  0           ['dropout_87[0][0]',
#                                 56)                               'conv3d_transpose_13[0][0]']
#
#  conv3d_70 (Conv3D)             (None, 8, 32, 32, 1  884864      ['concatenate_22[0][0]']
#                                 28)
#
#  batch_normalization_108 (Batch  (None, 8, 32, 32, 1  512        ['conv3d_70[0][0]']
#  Normalization)                 28)
#
#  activation_100 (Activation)    (None, 8, 32, 32, 1  0           ['batch_normalization_108[0][0]']
#                                 28)
#
#  dropout_94 (Dropout)           (None, 8, 32, 32, 1  0           ['activation_100[0][0]']
#                                 28)
#
#  conv3d_71 (Conv3D)             (None, 8, 32, 32, 1  442496      ['dropout_94[0][0]']
#                                 28)
#
#  batch_normalization_109 (Batch  (None, 8, 32, 32, 1  512        ['conv3d_71[0][0]']
#  Normalization)                 28)
#
#  activation_101 (Activation)    (None, 8, 32, 32, 1  0           ['batch_normalization_109[0][0]']
#                                 28)
#
#  dropout_95 (Dropout)           (None, 8, 32, 32, 1  0           ['activation_101[0][0]']
#                                 28)
#
#  conv3d_transpose_14 (Conv3DTra  (None, 16, 64, 64,   65600      ['dropout_95[0][0]']
#  nspose)                        64)
#
#  concatenate_23 (Concatenate)   (None, 16, 64, 64,   0           ['dropout_85[0][0]',
#                                 128)                              'conv3d_transpose_14[0][0]']
#
#  conv3d_72 (Conv3D)             (None, 16, 64, 64,   221248      ['concatenate_23[0][0]']
#                                 64)
#
#  batch_normalization_110 (Batch  (None, 16, 64, 64,   256        ['conv3d_72[0][0]']
#  Normalization)                 64)
#
#  activation_102 (Activation)    (None, 16, 64, 64,   0           ['batch_normalization_110[0][0]']
#                                 64)
#
#  dropout_96 (Dropout)           (None, 16, 64, 64,   0           ['activation_102[0][0]']
#                                 64)
#
#  conv3d_73 (Conv3D)             (None, 16, 64, 64,   110656      ['dropout_96[0][0]']
#                                 64)
#
#  batch_normalization_111 (Batch  (None, 16, 64, 64,   256        ['conv3d_73[0][0]']
#  Normalization)                 64)
#
#  activation_103 (Activation)    (None, 16, 64, 64,   0           ['batch_normalization_111[0][0]']
#                                 64)
#
#  dropout_97 (Dropout)           (None, 16, 64, 64,   0           ['activation_103[0][0]']
#                                 64)
#
#  conv3d_74 (Conv3D)             (None, 16, 64, 64,   195         ['dropout_97[0][0]']
#                                 3)
#
#  activation_104 (Activation)    (None, 16, 64, 64,   0           ['conv3d_74[0][0]']
#                                 3)
#
#  relu_normalization_6 (ReluNorm  (None, 16, 64, 64,   0          ['activation_104[0][0]']
#  alization)                     3)
#
# ==================================================================================================
# Total params: 14,800,451
# Trainable params: 14,795,843
# Non-trainable params: 4,608
# __________________________________________________________________________________________________

# %% [markdown]
# # Pratical test

# %%
unet2dLoader = unet.UNet([96,96,3], n_class=3, depth=4, top_activation="relu", n_feat=64, norm_order=1, dropout=0.4, activation='relu', backbone='vgg16')
unet2dLoader.load_weights("D:/Etude/LINUM/resultat/unet2d_optim_w_unlabeled7.h5")
transfer3d = ly.model2D_to_3D(unet2dLoader, 16)
transfer3d.save_weights("test2.h5")
transfer3d.summary()
# Out:
# Model: "model_42"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_45 (InputLayer)          [(None, 16, 96, 96,  0           []
#                                  3)]
#
#  conv3d_297 (Conv3D)            (None, 16, 96, 96,   5248        ['input_45[0][0]']
#                                 64)
#
#  conv3d_298 (Conv3D)            (None, 16, 96, 96,   110656      ['conv3d_297[0][0]']
#                                 64)
#
#  max_pooling3d_55 (MaxPooling3D  (None, 8, 48, 48, 6  0          ['conv3d_298[0][0]']
#  )                              4)
#
#  conv3d_299 (Conv3D)            (None, 8, 48, 48, 1  221312      ['max_pooling3d_55[0][0]']
#                                 28)
#
#  conv3d_300 (Conv3D)            (None, 8, 48, 48, 1  442496      ['conv3d_299[0][0]']
#                                 28)
#
#  max_pooling3d_56 (MaxPooling3D  (None, 4, 24, 24, 1  0          ['conv3d_300[0][0]']
#  )                              28)
#
#  conv3d_301 (Conv3D)            (None, 4, 24, 24, 2  884992      ['max_pooling3d_56[0][0]']
#                                 56)
#
#  conv3d_302 (Conv3D)            (None, 4, 24, 24, 2  1769728     ['conv3d_301[0][0]']
#                                 56)
#
#  conv3d_303 (Conv3D)            (None, 4, 24, 24, 2  1769728     ['conv3d_302[0][0]']
#                                 56)
#
#  max_pooling3d_57 (MaxPooling3D  (None, 2, 12, 12, 2  0          ['conv3d_303[0][0]']
#  )                              56)
#
#  conv3d_304 (Conv3D)            (None, 2, 12, 12, 5  3539456     ['max_pooling3d_57[0][0]']
#                                 12)
#
#  conv3d_305 (Conv3D)            (None, 2, 12, 12, 5  7078400     ['conv3d_304[0][0]']
#                                 12)
#
#  conv3d_306 (Conv3D)            (None, 2, 12, 12, 5  7078400     ['conv3d_305[0][0]']
#                                 12)
#
#  max_pooling3d_58 (MaxPooling3D  (None, 1, 6, 6, 512  0          ['conv3d_306[0][0]']
#  )                              )
#
#  conv3d_307 (Conv3D)            (None, 1, 6, 6, 512  7078400     ['max_pooling3d_58[0][0]']
#                                 )
#
#  conv3d_308 (Conv3D)            (None, 1, 6, 6, 512  7078400     ['conv3d_307[0][0]']
#                                 )
#
#  conv3d_309 (Conv3D)            (None, 1, 6, 6, 512  7078400     ['conv3d_308[0][0]']
#                                 )
#
#  conv3d_transpose_55 (Conv3DTra  (None, 2, 12, 12, 5  2097664    ['conv3d_309[0][0]']
#  nspose)                        12)
#
#  concatenate_84 (Concatenate)   (None, 2, 12, 12, 1  0           ['conv3d_306[0][0]',
#                                 024)                              'conv3d_transpose_55[0][0]']
#
#  conv3d_310 (Conv3D)            (None, 2, 12, 12, 5  14156288    ['concatenate_84[0][0]']
#                                 12)
#
#  activation_204 (Activation)    multiple             0           ['conv3d_310[0][0]']
#
#  dropout_186 (Dropout)          multiple             0           ['activation_204[1][0]']
#
#  batch_normalization_232 (Batch  (None, 2, 12, 12, 5  2048       ['dropout_186[1][0]']
#  Normalization)                 12)
#
#  conv3d_311 (Conv3D)            (None, 2, 12, 12, 5  7078400     ['batch_normalization_232[0][0]']
#                                 12)
#
#  activation_205 (Activation)    multiple             0           ['conv3d_311[0][0]']
#
#  dropout_187 (Dropout)          multiple             0           ['activation_205[1][0]']
#
#  batch_normalization_233 (Batch  (None, 2, 12, 12, 5  2048       ['dropout_187[1][0]']
#  Normalization)                 12)
#
#  conv3d_transpose_56 (Conv3DTra  (None, 4, 24, 24, 2  1048832    ['batch_normalization_233[0][0]']
#  nspose)                        56)
#
#  concatenate_85 (Concatenate)   (None, 4, 24, 24, 5  0           ['conv3d_303[0][0]',
#                                 12)                               'conv3d_transpose_56[0][0]']
#
#  conv3d_312 (Conv3D)            (None, 4, 24, 24, 2  3539200     ['concatenate_85[0][0]']
#                                 56)
#
#  activation_206 (Activation)    multiple             0           ['conv3d_312[0][0]']
#
#  dropout_188 (Dropout)          multiple             0           ['activation_206[1][0]']
#
#  batch_normalization_234 (Batch  (None, 4, 24, 24, 2  1024       ['dropout_188[1][0]']
#  Normalization)                 56)
#
#  conv3d_313 (Conv3D)            (None, 4, 24, 24, 2  1769728     ['batch_normalization_234[0][0]']
#                                 56)
#
#  activation_207 (Activation)    multiple             0           ['conv3d_313[0][0]']
#
#  dropout_189 (Dropout)          multiple             0           ['activation_207[1][0]']
#
#  batch_normalization_235 (Batch  (None, 4, 24, 24, 2  1024       ['dropout_189[1][0]']
#  Normalization)                 56)
#
#  conv3d_transpose_57 (Conv3DTra  (None, 8, 48, 48, 1  262272     ['batch_normalization_235[0][0]']
#  nspose)                        28)
#
#  concatenate_86 (Concatenate)   (None, 8, 48, 48, 2  0           ['conv3d_300[0][0]',
#                                 56)                               'conv3d_transpose_57[0][0]']
#
#  conv3d_314 (Conv3D)            (None, 8, 48, 48, 1  884864      ['concatenate_86[0][0]']
#                                 28)
#
#  activation_208 (Activation)    multiple             0           ['conv3d_314[0][0]']
#
#  dropout_190 (Dropout)          multiple             0           ['activation_208[1][0]']
#
#  batch_normalization_236 (Batch  (None, 8, 48, 48, 1  512        ['dropout_190[1][0]']
#  Normalization)                 28)
#
#  conv3d_315 (Conv3D)            (None, 8, 48, 48, 1  442496      ['batch_normalization_236[0][0]']
#                                 28)
#
#  activation_209 (Activation)    multiple             0           ['conv3d_315[0][0]']
#
#  dropout_191 (Dropout)          multiple             0           ['activation_209[1][0]']
#
#  batch_normalization_237 (Batch  (None, 8, 48, 48, 1  512        ['dropout_191[1][0]']
#  Normalization)                 28)
#
#  conv3d_transpose_58 (Conv3DTra  (None, 16, 96, 96,   65600      ['batch_normalization_237[0][0]']
#  nspose)                        64)
#
#  concatenate_87 (Concatenate)   (None, 16, 96, 96,   0           ['conv3d_298[0][0]',
#                                 128)                              'conv3d_transpose_58[0][0]']
#
#  conv3d_316 (Conv3D)            (None, 16, 96, 96,   221248      ['concatenate_87[0][0]']
#                                 64)
#
#  activation_210 (Activation)    multiple             0           ['conv3d_316[0][0]']
#
#  dropout_192 (Dropout)          multiple             0           ['activation_210[1][0]']
#
#  batch_normalization_238 (Batch  (None, 16, 96, 96,   256        ['dropout_192[1][0]']
#  Normalization)                 64)
#
#  conv3d_317 (Conv3D)            (None, 16, 96, 96,   110656      ['batch_normalization_238[0][0]']
#                                 64)
#
#  activation_211 (Activation)    multiple             0           ['conv3d_317[0][0]']
#
#  dropout_193 (Dropout)          multiple             0           ['activation_211[1][0]']
#
#  batch_normalization_239 (Batch  (None, 16, 96, 96,   256        ['dropout_193[1][0]']
#  Normalization)                 64)
#
#  conv3d_318 (Conv3D)            (None, 16, 96, 96,   195         ['batch_normalization_239[0][0]']
#                                 3)
#
#  activation_212 (Activation)    multiple             0           ['conv3d_318[0][0]']
#
#  relu_normalization_18 (ReluNor  multiple            0           ['activation_212[1][0]']
#  malization)
#
# ==================================================================================================
# Total params: 75,820,739
# Trainable params: 75,816,899
# Non-trainable params: 3,840
# __________________________________________________________________________________________________

# %%
# change input shape
unet3dLoader = unet.UNet([16,64,64,3], n_class=3, depth=4, top_activation="relu", n_feat=64, norm_order=1, dropout=0.4, activation='relu', backbone='vgg16')
unet3dLoader.load_weights("test2.h5")
unet3dLoader.summary()
# Out:
# Model: "model_48"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_49 (InputLayer)          [(None, 16, 64, 64,  0           []
#                                  3)]
#
#  conv3d_341 (Conv3D)            (None, 16, 64, 64,   5248        ['input_49[0][0]']
#                                 64)
#
#  conv3d_342 (Conv3D)            (None, 16, 64, 64,   110656      ['conv3d_341[1][0]']
#                                 64)
#
#  max_pooling3d_63 (MaxPooling3D  (None, 8, 32, 32, 6  0          ['conv3d_342[1][0]']
#  )                              4)
#
#  conv3d_343 (Conv3D)            (None, 8, 32, 32, 1  221312      ['max_pooling3d_63[1][0]']
#                                 28)
#
#  conv3d_344 (Conv3D)            (None, 8, 32, 32, 1  442496      ['conv3d_343[1][0]']
#                                 28)
#
#  max_pooling3d_64 (MaxPooling3D  (None, 4, 16, 16, 1  0          ['conv3d_344[1][0]']
#  )                              28)
#
#  conv3d_345 (Conv3D)            (None, 4, 16, 16, 2  884992      ['max_pooling3d_64[1][0]']
#                                 56)
#
#  conv3d_346 (Conv3D)            (None, 4, 16, 16, 2  1769728     ['conv3d_345[1][0]']
#                                 56)
#
#  conv3d_347 (Conv3D)            (None, 4, 16, 16, 2  1769728     ['conv3d_346[1][0]']
#                                 56)
#
#  max_pooling3d_65 (MaxPooling3D  (None, 2, 8, 8, 256  0          ['conv3d_347[1][0]']
#  )                              )
#
#  conv3d_348 (Conv3D)            (None, 2, 8, 8, 512  3539456     ['max_pooling3d_65[1][0]']
#                                 )
#
#  conv3d_349 (Conv3D)            (None, 2, 8, 8, 512  7078400     ['conv3d_348[1][0]']
#                                 )
#
#  conv3d_350 (Conv3D)            (None, 2, 8, 8, 512  7078400     ['conv3d_349[1][0]']
#                                 )
#
#  max_pooling3d_66 (MaxPooling3D  (None, 1, 4, 4, 512  0          ['conv3d_350[1][0]']
#  )                              )
#
#  conv3d_351 (Conv3D)            (None, 1, 4, 4, 512  7078400     ['max_pooling3d_66[1][0]']
#                                 )
#
#  conv3d_352 (Conv3D)            (None, 1, 4, 4, 512  7078400     ['conv3d_351[1][0]']
#                                 )
#
#  conv3d_353 (Conv3D)            (None, 1, 4, 4, 512  7078400     ['conv3d_352[1][0]']
#                                 )
#
#  conv3d_transpose_63 (Conv3DTra  (None, 2, 8, 8, 512  2097664    ['conv3d_353[1][0]']
#  nspose)                        )
#
#  concatenate_92 (Concatenate)   (None, 2, 8, 8, 102  0           ['conv3d_350[1][0]',
#                                 4)                                'conv3d_transpose_63[0][0]']
#
#  conv3d_354 (Conv3D)            (None, 2, 8, 8, 512  14156288    ['concatenate_92[0][0]']
#                                 )
#
#  activation_222 (Activation)    (None, 2, 8, 8, 512  0           ['conv3d_354[0][0]']
#                                 )
#
#  dropout_202 (Dropout)          (None, 2, 8, 8, 512  0           ['activation_222[0][0]']
#                                 )
#
#  batch_normalization_248 (Batch  (None, 2, 8, 8, 512  2048       ['dropout_202[0][0]']
#  Normalization)                 )
#
#  conv3d_355 (Conv3D)            (None, 2, 8, 8, 512  7078400     ['batch_normalization_248[0][0]']
#                                 )
#
#  activation_223 (Activation)    (None, 2, 8, 8, 512  0           ['conv3d_355[0][0]']
#                                 )
#
#  dropout_203 (Dropout)          (None, 2, 8, 8, 512  0           ['activation_223[0][0]']
#                                 )
#
#  batch_normalization_249 (Batch  (None, 2, 8, 8, 512  2048       ['dropout_203[0][0]']
#  Normalization)                 )
#
#  conv3d_transpose_64 (Conv3DTra  (None, 4, 16, 16, 2  1048832    ['batch_normalization_249[0][0]']
#  nspose)                        56)
#
#  concatenate_93 (Concatenate)   (None, 4, 16, 16, 5  0           ['conv3d_347[1][0]',
#                                 12)                               'conv3d_transpose_64[0][0]']
#
#  conv3d_356 (Conv3D)            (None, 4, 16, 16, 2  3539200     ['concatenate_93[0][0]']
#                                 56)
#
#  activation_224 (Activation)    (None, 4, 16, 16, 2  0           ['conv3d_356[0][0]']
#                                 56)
#
#  dropout_204 (Dropout)          (None, 4, 16, 16, 2  0           ['activation_224[0][0]']
#                                 56)
#
#  batch_normalization_250 (Batch  (None, 4, 16, 16, 2  1024       ['dropout_204[0][0]']
#  Normalization)                 56)
#
#  conv3d_357 (Conv3D)            (None, 4, 16, 16, 2  1769728     ['batch_normalization_250[0][0]']
#                                 56)
#
#  activation_225 (Activation)    (None, 4, 16, 16, 2  0           ['conv3d_357[0][0]']
#                                 56)
#
#  dropout_205 (Dropout)          (None, 4, 16, 16, 2  0           ['activation_225[0][0]']
#                                 56)
#
#  batch_normalization_251 (Batch  (None, 4, 16, 16, 2  1024       ['dropout_205[0][0]']
#  Normalization)                 56)
#
#  conv3d_transpose_65 (Conv3DTra  (None, 8, 32, 32, 1  262272     ['batch_normalization_251[0][0]']
#  nspose)                        28)
#
#  concatenate_94 (Concatenate)   (None, 8, 32, 32, 2  0           ['conv3d_344[1][0]',
#                                 56)                               'conv3d_transpose_65[0][0]']
#
#  conv3d_358 (Conv3D)            (None, 8, 32, 32, 1  884864      ['concatenate_94[0][0]']
#                                 28)
#
#  activation_226 (Activation)    (None, 8, 32, 32, 1  0           ['conv3d_358[0][0]']
#                                 28)
#
#  dropout_206 (Dropout)          (None, 8, 32, 32, 1  0           ['activation_226[0][0]']
#                                 28)
#
#  batch_normalization_252 (Batch  (None, 8, 32, 32, 1  512        ['dropout_206[0][0]']
#  Normalization)                 28)
#
#  conv3d_359 (Conv3D)            (None, 8, 32, 32, 1  442496      ['batch_normalization_252[0][0]']
#                                 28)
#
#  activation_227 (Activation)    (None, 8, 32, 32, 1  0           ['conv3d_359[0][0]']
#                                 28)
#
#  dropout_207 (Dropout)          (None, 8, 32, 32, 1  0           ['activation_227[0][0]']
#                                 28)
#
#  batch_normalization_253 (Batch  (None, 8, 32, 32, 1  512        ['dropout_207[0][0]']
#  Normalization)                 28)
#
#  conv3d_transpose_66 (Conv3DTra  (None, 16, 64, 64,   65600      ['batch_normalization_253[0][0]']
#  nspose)                        64)
#
#  concatenate_95 (Concatenate)   (None, 16, 64, 64,   0           ['conv3d_342[1][0]',
#                                 128)                              'conv3d_transpose_66[0][0]']
#
#  conv3d_360 (Conv3D)            (None, 16, 64, 64,   221248      ['concatenate_95[0][0]']
#                                 64)
#
#  activation_228 (Activation)    (None, 16, 64, 64,   0           ['conv3d_360[0][0]']
#                                 64)
#
#  dropout_208 (Dropout)          (None, 16, 64, 64,   0           ['activation_228[0][0]']
#                                 64)
#
#  batch_normalization_254 (Batch  (None, 16, 64, 64,   256        ['dropout_208[0][0]']
#  Normalization)                 64)
#
#  conv3d_361 (Conv3D)            (None, 16, 64, 64,   110656      ['batch_normalization_254[0][0]']
#                                 64)
#
#  activation_229 (Activation)    (None, 16, 64, 64,   0           ['conv3d_361[0][0]']
#                                 64)
#
#  dropout_209 (Dropout)          (None, 16, 64, 64,   0           ['activation_229[0][0]']
#                                 64)
#
#  batch_normalization_255 (Batch  (None, 16, 64, 64,   256        ['dropout_209[0][0]']
#  Normalization)                 64)
#
#  conv3d_362 (Conv3D)            (None, 16, 64, 64,   195         ['batch_normalization_255[0][0]']
#                                 3)
#
#  activation_230 (Activation)    (None, 16, 64, 64,   0           ['conv3d_362[0][0]']
#                                 3)
#
#  relu_normalization_20 (ReluNor  (None, 16, 64, 64,   0          ['activation_230[0][0]']
#  malization)                    3)
#
# ==================================================================================================
# Total params: 75,820,739
# Trainable params: 75,816,899
# Non-trainable params: 3,840
# __________________________________________________________________________________________________
