# %% [markdown]
# # Transfer learning
# Transfer learning is a vital part for saving time during model training

# %%
import tifffile as tif
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import carreno.nn.unet as unet

# %% [markdown]
# ## 2D weights to 3D
# We would like to transfer the weights from a 2D UNet to a 3D UNet

# %%
help(unet.UNet.__init__)
# Out:
# Help on function __init__ in module carreno.nn.unet:
#
# __init__(self, shape, n_class=3, depth=3, n_feat=32)
#     Create a UNet architecture
#     Parameters
#     ----------
#     shape : (int, int, int)
#         Image shape. Even if grayscale, we must have a color channel
#     n_class : int
#         Number of unique labels
#     depth : int
#         UNet number of levels (nb of encoder block + 1)
#     n_feat : int
#         Number of features for the first encoder block (will increase and decrease according to UNet architecture)
#     Returns
#     -------
#     model : tf.keras.Model
#         Keras model waiting to be compiled for training

# %%
# create 2D UNet
unet2D = unet.UNet([64,64,1], n_class=3, depth=3)
model = unet2D.model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 64, 64, 32)   320         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64, 64, 32)  128         ['conv2d[0][0]']
#  alization)
#
#  leaky_re_lu (LeakyReLU)        (None, 64, 64, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 32)   9248        ['leaky_re_lu[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_1[0][0]']
#  rmalization)
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 64, 64, 32)   0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 32)   0           ['leaky_re_lu_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 64)   18496       ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 32, 32, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 64)   36928       ['leaky_re_lu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 32, 32, 64)   0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)  0           ['leaky_re_lu_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 16, 16, 128)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 128)  147584      ['leaky_re_lu_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 16, 16, 128)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 64)  32832       ['leaky_re_lu_5[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 128)  0           ['conv2d_transpose[0][0]',
#                                                                   'leaky_re_lu_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 64)   73792       ['concatenate[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 32, 32, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 64)   36928       ['leaky_re_lu_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 32, 32, 64)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 32)  8224        ['leaky_re_lu_7[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_1[0][0]',
#                                                                   'leaky_re_lu_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 32)   18464       ['concatenate_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_8[0][0]']
#  rmalization)
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 64, 64, 32)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 32)   9248        ['leaky_re_lu_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_9[0][0]']
#  rmalization)
#
#  leaky_re_lu_9 (LeakyReLU)      (None, 64, 64, 32)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 3)    99          ['leaky_re_lu_9[0][0]']
#
# ==================================================================================================
# Total params: 468,579
# Trainable params: 467,299
# Non-trainable params: 1,280
# __________________________________________________________________________________________________

# %%
# set fake weights
layer = model.layers[1].get_weights()[0]
layer[:] = 1  # all weights will be 1
model.layers[1].set_weights([layer, model.layers[1].get_weights()[1]])

# %%
# create 3D UNet from 2D UNet
unet3D = unet.unet2D_to_unet3D(model, [64,64,64,1])

# %%
# if everything went well, our fake weights should be averaged in this layer
layer3D = unet3D.layers[1].get_weights()[0]
print("Old shape :", layer.shape)
print("New shape :", layer3D.shape)
print('---')
print("Old weights :", np.unique(layer))
print("New weights :", np.unique(layer3D))
# Out:
# Old shape : (3, 3, 1, 32)
# New shape : (3, 3, 3, 1, 32)
# ---
# Old weights : [1.]
# New weights : [0.33333334]

# %%
unet3D.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 64, 64, 64,  0           []
#                                  1)]
#
#  conv3d (Conv3D)                (None, 64, 64, 64,   896         ['input_2[0][0]']
#                                 32)
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 64,   128        ['conv3d[0][0]']
#  ormalization)                  32)
#
#  leaky_re_lu_10 (LeakyReLU)     (None, 64, 64, 64,   0           ['batch_normalization_10[0][0]']
#                                 32)
#
#  conv3d_1 (Conv3D)              (None, 64, 64, 64,   27680       ['leaky_re_lu_10[0][0]']
#                                 32)
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 64,   128        ['conv3d_1[0][0]']
#  ormalization)                  32)
#
#  leaky_re_lu_11 (LeakyReLU)     (None, 64, 64, 64,   0           ['batch_normalization_11[0][0]']
#                                 32)
#
#  max_pooling3d (MaxPooling3D)   (None, 32, 32, 32,   0           ['leaky_re_lu_11[0][0]']
#                                 32)
#
#  conv3d_2 (Conv3D)              (None, 32, 32, 32,   55360       ['max_pooling3d[0][0]']
#                                 64)
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 32,   256        ['conv3d_2[0][0]']
#  ormalization)                  64)
#
#  leaky_re_lu_12 (LeakyReLU)     (None, 32, 32, 32,   0           ['batch_normalization_12[0][0]']
#                                 64)
#
#  conv3d_3 (Conv3D)              (None, 32, 32, 32,   110656      ['leaky_re_lu_12[0][0]']
#                                 64)
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 32,   256        ['conv3d_3[0][0]']
#  ormalization)                  64)
#
#  leaky_re_lu_13 (LeakyReLU)     (None, 32, 32, 32,   0           ['batch_normalization_13[0][0]']
#                                 64)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 16, 16, 16,   0          ['leaky_re_lu_13[0][0]']
#                                 64)
#
#  conv3d_4 (Conv3D)              (None, 16, 16, 16,   221312      ['max_pooling3d_1[0][0]']
#                                 128)
#
#  batch_normalization_14 (BatchN  (None, 16, 16, 16,   512        ['conv3d_4[0][0]']
#  ormalization)                  128)
#
#  leaky_re_lu_14 (LeakyReLU)     (None, 16, 16, 16,   0           ['batch_normalization_14[0][0]']
#                                 128)
#
#  conv3d_5 (Conv3D)              (None, 16, 16, 16,   442496      ['leaky_re_lu_14[0][0]']
#                                 128)
#
#  batch_normalization_15 (BatchN  (None, 16, 16, 16,   512        ['conv3d_5[0][0]']
#  ormalization)                  128)
#
#  leaky_re_lu_15 (LeakyReLU)     (None, 16, 16, 16,   0           ['batch_normalization_15[0][0]']
#                                 128)
#
#  conv3d_transpose (Conv3DTransp  (None, 32, 32, 32,   65600      ['leaky_re_lu_15[0][0]']
#  ose)                           64)
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose[0][0]',
#                                 128)                              'leaky_re_lu_13[0][0]']
#
#  conv3d_6 (Conv3D)              (None, 32, 32, 32,   221248      ['concatenate_2[0][0]']
#                                 64)
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 32,   256        ['conv3d_6[0][0]']
#  ormalization)                  64)
#
#  leaky_re_lu_16 (LeakyReLU)     (None, 32, 32, 32,   0           ['batch_normalization_16[0][0]']
#                                 64)
#
#  conv3d_7 (Conv3D)              (None, 32, 32, 32,   110656      ['leaky_re_lu_16[0][0]']
#                                 64)
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 32,   256        ['conv3d_7[0][0]']
#  ormalization)                  64)
#
#  leaky_re_lu_17 (LeakyReLU)     (None, 32, 32, 32,   0           ['batch_normalization_17[0][0]']
#                                 64)
#
#  conv3d_transpose_1 (Conv3DTran  (None, 64, 64, 64,   16416      ['leaky_re_lu_17[0][0]']
#  spose)                         32)
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_1[0][0]',
#                                 64)                               'leaky_re_lu_11[0][0]']
#
#  conv3d_8 (Conv3D)              (None, 64, 64, 64,   55328       ['concatenate_3[0][0]']
#                                 32)
#
#  batch_normalization_18 (BatchN  (None, 64, 64, 64,   128        ['conv3d_8[0][0]']
#  ormalization)                  32)
#
#  leaky_re_lu_18 (LeakyReLU)     (None, 64, 64, 64,   0           ['batch_normalization_18[0][0]']
#                                 32)
#
#  conv3d_9 (Conv3D)              (None, 64, 64, 64,   27680       ['leaky_re_lu_18[0][0]']
#                                 32)
#
#  batch_normalization_19 (BatchN  (None, 64, 64, 64,   128        ['conv3d_9[0][0]']
#  ormalization)                  32)
#
#  leaky_re_lu_19 (LeakyReLU)     (None, 64, 64, 64,   0           ['batch_normalization_19[0][0]']
#                                 32)
#
#  conv3d_10 (Conv3D)             (None, 64, 64, 64,   99          ['leaky_re_lu_19[0][0]']
#                                 3)
#
# ==================================================================================================
# Total params: 1,357,987
# Trainable params: 1,356,707
# Non-trainable params: 1,280
# __________________________________________________________________________________________________

# %%
# we could use an approach which map every layer name with a 2D and 3D fonction for a very general conversion
inp = tf.keras.layers.Input([64, 64, 64, 1])
print("nb layers", len(model.layers))
for i, layer in enumerate(model.layers):
    name = layer.name.rsplit('_', 1)[0]
    print('-layer{:<2} {:<20}'.format(i, name), end="")
    
    t = "?"
    input_name = 'input'
    conv2d_name = 'conv2d'
    conv2d_transpose_name = 'conv2d_transpose'
    batch_norm_name = 'batch_normalization'
    leaky_relu_name = 'leaky_re_lu'
    max_pooling2d_name = 'max_pooling2d'
    concatenate_name = 'concatenate'
    
    if input_name == name:
        t = input_name
    elif conv2d_name == name:
        t = conv2d_name
    elif conv2d_transpose_name == name:
        t = conv2d_transpose_name
    elif batch_norm_name == name:
        t = batch_norm_name
    elif leaky_relu_name == name:
        t = leaky_relu_name
    elif max_pooling2d_name == name:
        t = max_pooling2d_name
    elif concatenate_name == name:
        t = concatenate_name
    
    print(' type {:<20}'.format(t), 'do something?', '2d' in name or name == concatenate_name)
# Out:
# nb layers 38
# -layer0  input                type input                do something? False
# -layer1  conv2d               type conv2d               do something? True
# -layer2  batch_normalization  type batch_normalization  do something? False
# -layer3  leaky_re_lu          type leaky_re_lu          do something? False
# -layer4  conv2d               type conv2d               do something? True
# -layer5  batch_normalization  type batch_normalization  do something? False
# -layer6  leaky_re_lu          type leaky_re_lu          do something? False
# -layer7  max_pooling2d        type max_pooling2d        do something? True
# -layer8  conv2d               type conv2d               do something? True
# -layer9  batch_normalization  type batch_normalization  do something? False
# -layer10 leaky_re_lu          type leaky_re_lu          do something? False
# -layer11 conv2d               type conv2d               do something? True
# -layer12 batch_normalization  type batch_normalization  do something? False
# -layer13 leaky_re_lu          type leaky_re_lu          do something? False
# -layer14 max_pooling2d        type max_pooling2d        do something? True
# -layer15 conv2d               type conv2d               do something? True
# -layer16 batch_normalization  type batch_normalization  do something? False
# -layer17 leaky_re_lu          type leaky_re_lu          do something? False
# -layer18 conv2d               type conv2d               do something? True
# -layer19 batch_normalization  type batch_normalization  do something? False
# -layer20 leaky_re_lu          type leaky_re_lu          do something? False
# -layer21 conv2d_transpose     type conv2d_transpose     do something? True
# -layer22 concatenate          type concatenate          do something? True
# -layer23 conv2d               type conv2d               do something? True
# -layer24 batch_normalization  type batch_normalization  do something? False
# -layer25 leaky_re_lu          type leaky_re_lu          do something? False
# -layer26 conv2d               type conv2d               do something? True
# -layer27 batch_normalization  type batch_normalization  do something? False
# -layer28 leaky_re_lu          type leaky_re_lu          do something? False
# -layer29 conv2d_transpose     type conv2d_transpose     do something? True
# -layer30 concatenate          type concatenate          do something? True
# -layer31 conv2d               type conv2d               do something? True
# -layer32 batch_normalization  type batch_normalization  do something? False
# -layer33 leaky_re_lu          type leaky_re_lu          do something? False
# -layer34 conv2d               type conv2d               do something? True
# -layer35 batch_normalization  type batch_normalization  do something? False
# -layer36 leaky_re_lu          type leaky_re_lu          do something? False
# -layer37 conv2d               type conv2d               do something? True
